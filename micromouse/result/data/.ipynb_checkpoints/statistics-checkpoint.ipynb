# %%
import pandas as pd
import numpy as np

# %%
def maze_summary(dataframe, category):
    '''
    Calculate the means and standard deviations of certain categories in the dataframe.
    dataframe: data table, pandas dataframe
    category: user specified categories for calculation, python list
    '''
    maze_list = dataframe['maze'].unique().tolist()
    mode_list = dataframe['mode'].unique().tolist()
    intuition_list = dataframe['intuition'].unique().tolist()
    heuristic_list = dataframe['heuristic'].unique().tolist()
    summary_mean = pd.DataFrame()
    summary_std = pd.DataFrame()
    for maze in maze_list:
        for mode in mode_list:
            for intuition in intuition_list:
                for heuristic in heuristic_list:
                    data = dataframe[(dataframe['maze'] == maze) & (dataframe['mode'] == mode) & (dataframe['intuition'] == intuition) & (dataframe['heuristic'] == heuristic)][category]
                    data_mean = np.around(data.mean().values, decimals = 2).tolist()
                    data_std = np.around(data.std().values, decimals = 2).tolist()
                    summary_mean = summary_mean.append([[maze, mode, intuition, heuristic] + data_mean], ignore_index = True)
                    summary_std = summary_std.append([[maze, mode, intuition, heuristic] + data_std], ignore_index = True)
    return (summary_mean, summary_std)

# %%
def file_process(file_list):
    '''
    Process files for maze_summary.
    file_list: file name list, python list
    '''
    summary_mean = pd.DataFrame()
    summary_std = pd.DataFrame()
    for file in file_list:
        dataframe = pd.read_csv(file, sep = ',')
        category = dataframe.columns.values.tolist()[4:]
        summary = maze_summary(dataframe = dataframe, category = category)
        summary_mean = summary_mean.append(summary[0], ignore_index = True)
        summary_std = summary_std.append(summary[1], ignore_index = True)
    return (summary_mean, summary_std)

# %%
def summary_process(dataframe_list):
    '''
    Merge statistics of multiple dataframe in a list.
    dataframe_list: dataframe list, python list
    '''
    summary_mean = pd.DataFrame()
    summary_std = pd.DataFrame()
    for dataframe in dataframe_list:
        category = dataframe.columns.values.tolist()[4:]
        summary = maze_summary(dataframe = dataframe, category = category)
        summary_mean = summary_mean.append(summary[0], ignore_index = True)
        summary_std = summary_std.append(summary[1], ignore_index = True)
    return (summary_mean, summary_std)

# %%
file_list = ['test_result_maze_01.csv', 'test_result_maze_02.csv', 'test_result_maze_03.csv']

# %%
dataframe_list = list()
for file in file_list:
    dataframe_list.append(pd.read_csv(file, sep = ','))

# %%
# Take a look at the data
dataframe_list[0].head()
# Out:
#    maze      mode intuition heuristic  num_actions_1  length_movement_1  \
# 0     1  complete     False     False          190.0              223.0
# 1     1  complete     False     False          190.0              223.0
# 2     1  complete     False     False          176.0              203.0
# 3     1  complete     False     False          183.0              221.0
# 4     1  complete     False     False          187.0              210.0
#
#    num_actions_2  length_movement_2  num_actions_3  length_movement_3  \
# 0           11.0               17.0           17.0               32.0
# 1           11.0               17.0           17.0               32.0
# 2           12.0               21.0           17.0               32.0
# 3           18.0               31.0           17.0               32.0
# 4            9.0               18.0           17.0               32.0
#
#    true_coverage      score  exploration_time  computation_time
# 0            1.0  23.700000           549.488           549.858
# 1            1.0  23.700000           591.497           591.880
# 2            1.0  23.266667           365.862           366.253
# 3            1.0  23.700000           394.488           394.887
# 4            1.0  23.533333           403.505           403.874

# %%
# Add maze_size information
# Calculate exploration efficiency
maze_size_dict = {1: 144, 2: 196, 3: 256}
for i in xrange(len(dataframe_list)):
    dataframe_list[i]['maze_size'] = dataframe_list[i]['maze'].map(lambda x: maze_size_dict[x])
    dataframe_list[i]['num_grid_per_action_1'] = dataframe_list[i]['maze_size'] * dataframe_list[i]['true_coverage'] / dataframe_list[i]['num_actions_1']
    dataframe_list[i]['num_grid_per_length_1'] = dataframe_list[i]['maze_size'] * dataframe_list[i]['true_coverage'] / dataframe_list[i]['length_movement_1']

# %%
dataframe_list[0].head()
# Out:
#    maze      mode intuition heuristic  num_actions_1  length_movement_1  \
# 0     1  complete     False     False          190.0              223.0
# 1     1  complete     False     False          190.0              223.0
# 2     1  complete     False     False          176.0              203.0
# 3     1  complete     False     False          183.0              221.0
# 4     1  complete     False     False          187.0              210.0
#
#    num_actions_2  length_movement_2  num_actions_3  length_movement_3  \
# 0           11.0               17.0           17.0               32.0
# 1           11.0               17.0           17.0               32.0
# 2           12.0               21.0           17.0               32.0
# 3           18.0               31.0           17.0               32.0
# 4            9.0               18.0           17.0               32.0
#
#    true_coverage      score  exploration_time  computation_time  maze_size  \
# 0            1.0  23.700000           549.488           549.858        144
# 1            1.0  23.700000           591.497           591.880        144
# 2            1.0  23.266667           365.862           366.253        144
# 3            1.0  23.700000           394.488           394.887        144
# 4            1.0  23.533333           403.505           403.874        144
#
#    num_grid_per_action_1  num_grid_per_length_1
# 0               0.757895               0.645740
# 1               0.757895               0.645740
# 2               0.818182               0.709360
# 3               0.786885               0.651584
# 4               0.770053               0.685714

# %%
column_names = ['Maze', 'Mode', 'Intuition', 'Heuristics', 'Time Steps 1', 'Path Length 1', 
                'Time Steps 2', 'Path Length 2', 'Time Steps 3', 'Path Length 3','Coverage', 'Score', 'Exploration Time', 'Computation Time', 'Maze Size', 'Number of Grid Visited Per Time Step during Exploration', 'Number of Grid Visited Per Path Length during Exploration']

# %%
summary = summary_process(dataframe_list)
summary_mean = summary[0]
summary_std = summary[1]

# %%
summary_mean.columns = column_names
summary_std.columns = column_names

# %%
summary_mean
# Out:
#     Maze        Mode Intuition Heuristics  Time Steps 1  Path Length 1  \
# 0      1    complete     False      False         185.5          220.4
# 1      1    complete     False       True         189.1          225.7
# 2      1    complete      True      False         186.8          219.7
# 3      1    complete      True       True         186.1          216.5
# 4      1  incomplete     False      False         118.8          136.2
# 5      1  incomplete     False       True         133.7          150.8
# 6      1  incomplete      True      False         102.2          114.4
# 7      1  incomplete      True       True         141.5          161.8
# 8      2    complete     False      False         256.4          302.4
# 9      2    complete     False       True         268.1          323.8
# 10     2    complete      True      False         260.5          310.4
# 11     2    complete      True       True         257.5          307.8
# 12     2  incomplete     False      False         180.9          206.4
# 13     2  incomplete     False       True         165.1          189.4
# 14     2  incomplete      True      False         165.4          186.4
# 15     2  incomplete      True       True         176.2          203.4
# 16     3    complete     False      False         328.1          392.7
# 17     3    complete     False       True         344.5          417.0
# 18     3    complete      True      False         326.5          392.1
# 19     3    complete      True       True         344.5          432.4
# 20     3  incomplete     False      False         179.1          205.6
# 21     3  incomplete     False       True         207.5          237.8
# 22     3  incomplete      True      False         162.5          183.8
# 23     3  incomplete      True       True         247.1          288.5
#
#     Time Steps 2  Path Length 2  Time Steps 3  Path Length 3  Coverage  Score  \
# 0           11.6           20.4          17.0           32.0      1.00  23.57
# 1            9.0           15.9          17.0           32.0      1.00  23.60
# 2            7.6           15.1          17.0           32.0      1.00  23.48
# 3            9.6           17.3          17.0           32.0      1.00  23.52
# 4           18.3           31.2          18.3           32.4      0.70  22.87
# 5           17.8           31.8          17.8           33.2      0.79  22.85
# 6           18.4           31.2          18.4           32.2      0.64  22.42
# 7           17.3           30.6          17.3           32.4      0.82  22.59
# 8           12.7           22.2          22.0           43.0      1.00  30.97
# 9           13.9           26.0          22.0           43.0      1.00  31.40
# 10          12.4           22.8          22.0           43.0      1.00  31.10
# 11          13.0           22.0          22.0           43.0      1.00  31.02
# 12          22.7           43.2          22.7           43.2      0.77  29.49
# 13          24.1           45.2          24.1           45.2      0.70  30.41
# 14          24.7           43.4          24.7           43.6      0.71  31.04
# 15          23.5           43.6          23.5           43.6      0.74  30.16
# 16          15.8           30.9          25.0           49.0      1.00  36.46
# 17          12.8           26.0          25.0           49.0      1.00  36.91
# 18          10.7           20.5          25.0           49.0      1.00  36.24
# 19          17.0           33.2          25.0           49.0      1.00  37.05
# 20          26.9           51.2          26.9           52.0      0.60  33.77
# 21          25.5           49.6          25.5           49.8      0.68  33.27
# 22          26.1           50.2          26.1           50.4      0.56  32.39
# 23          25.0           49.5          25.0           49.5      0.79  34.07
#
#     Exploration Time  Computation Time  Maze Size  \
# 0             415.40            415.81      144.0
# 1             109.17            109.62      144.0
# 2              79.08             79.43      144.0
# 3              43.44             43.79      144.0
# 4             257.91            258.24      144.0
# 5              61.72             62.05      144.0
# 6              37.99             38.32      144.0
# 7              29.95             30.27      144.0
# 8             680.18            680.70      196.0
# 9             161.89            162.37      196.0
# 10            144.09            144.57      196.0
# 11             74.98             75.44      196.0
# 12            407.94            408.36      196.0
# 13             92.81             93.26      196.0
# 14             74.73             75.20      196.0
# 15             45.46             45.91      196.0
# 16           1671.30           1671.96      256.0
# 17            241.78            242.34      256.0
# 18            243.42            243.99      256.0
# 19            115.10            115.66      256.0
# 20            820.83            821.31      256.0
# 21            135.83            136.34      256.0
# 22            112.07            112.55      256.0
# 23             77.39             77.92      256.0
#
#     Number of Grid Visited Per Time Step during Exploration  \
# 0                                                0.78
# 1                                                0.76
# 2                                                0.77
# 3                                                0.77
# 4                                                0.88
# 5                                                0.86
# 6                                                0.91
# 7                                                0.84
# 8                                                0.77
# 9                                                0.73
# 10                                               0.75
# 11                                               0.76
# 12                                               0.85
# 13                                               0.86
# 14                                               0.86
# 15                                               0.83
# 16                                               0.78
# 17                                               0.74
# 18                                               0.79
# 19                                               0.75
# 20                                               0.89
# 21                                               0.86
# 22                                               0.91
# 23                                               0.83
#
#     Number of Grid Visited Per Path Length during Exploration
# 0                                                0.65
# 1                                                0.64
# 2                                                0.66
# 3                                                0.67
# 4                                                0.78
# 5                                                0.77
# 6                                                0.82
# 7                                                0.75
# 8                                                0.65
# 9                                                0.61
# 10                                               0.63
# 11                                               0.64
# 12                                               0.75
# 13                                               0.76
# 14                                               0.77
# 15                                               0.73
# 16                                               0.65
# 17                                               0.62
# 18                                               0.66
# 19                                               0.60
# 20                                               0.79
# 21                                               0.77
# 22                                               0.83
# 23                                               0.72

# %%
summary_std
# Out:
#     Maze        Mode Intuition Heuristics  Time Steps 1  Path Length 1  \
# 0      1    complete     False      False          5.36          10.53
# 1      1    complete     False       True          4.51           8.35
# 2      1    complete      True      False          4.96           6.17
# 3      1    complete      True       True          4.68           5.72
# 4      1  incomplete     False      False         52.05          65.01
# 5      1  incomplete     False       True         35.63          43.49
# 6      1  incomplete      True      False         30.77          38.65
# 7      1  incomplete      True       True         35.39          44.61
# 8      2    complete     False      False          9.70          16.62
# 9      2    complete     False       True          8.49          15.31
# 10     2    complete      True      False          7.84          11.73
# 11     2    complete      True       True          8.64          16.61
# 12     2  incomplete     False      False         56.12          72.07
# 13     2  incomplete     False       True         58.48          73.44
# 14     2  incomplete      True      False         53.22          64.51
# 15     2  incomplete      True       True         45.92          57.93
# 16     3    complete     False      False          7.84          16.00
# 17     3    complete     False       True         11.42          24.69
# 18     3    complete      True      False         12.41          24.90
# 19     3    complete      True       True         20.47          43.09
# 20     3  incomplete     False      False         96.08         118.35
# 21     3  incomplete     False       True         84.97         107.89
# 22     3  incomplete      True      False         93.91         114.82
# 23     3  incomplete      True       True         66.81          87.93
#
#     Time Steps 2  Path Length 2  Time Steps 3  Path Length 3  Coverage  Score  \
# 0           3.69           5.99          0.00           0.00      0.00   0.23
# 1           5.06           8.60          0.00           0.00      0.00   0.27
# 2           4.33           7.23          0.00           0.00      0.00   0.12
# 3           4.86           8.84          0.00           0.00      0.00   0.22
# 4           1.49           1.69          1.49           0.84      0.26   0.92
# 5           0.92           2.20          0.92           2.15      0.18   0.82
# 6           1.43           1.40          1.43           1.48      0.17   1.17
# 7           0.67           1.35          0.67           1.26      0.17   1.02
# 8           5.64          10.11          0.00           0.00      0.00   0.45
# 9           7.42          14.79          0.00           0.00      0.00   0.45
# 10          5.72          11.12          0.00           0.00      0.00   0.37
# 11          4.97           9.49          0.00           0.00      0.00   0.41
# 12          1.34           0.63          1.34           0.63      0.19   1.45
# 13          3.78           5.03          3.78           5.03      0.19   3.26
# 14          1.89           1.26          1.89           1.35      0.19   1.73
# 15          2.07           1.35          2.07           1.35      0.15   2.07
# 16          6.16          13.19          0.00           0.00      0.00   0.33
# 17          7.41          16.49          0.00           0.00      0.00   0.46
# 18          4.64          10.01          0.00           0.00      0.00   0.45
# 19          6.88          14.27          0.00           0.00      0.00   0.68
# 20          2.69           5.61          2.69           5.35      0.27   2.88
# 21          1.08           1.35          1.08           1.40      0.23   2.48
# 22          1.37           2.53          1.37           2.67      0.29   2.21
# 23          0.00           1.08          0.00           1.08      0.18   2.23
#
#     Exploration Time  Computation Time  Maze Size  \
# 0             128.94            128.91        0.0
# 1              14.47             14.50        0.0
# 2              20.15             20.14        0.0
# 3               2.78              2.79        0.0
# 4             131.54            131.55        0.0
# 5              18.44             18.44        0.0
# 6              21.37             21.37        0.0
# 7               9.40              9.42        0.0
# 8             157.31            157.34        0.0
# 9              12.70             12.71        0.0
# 10             44.90             44.89        0.0
# 11              7.10              7.11        0.0
# 12            170.44            170.46        0.0
# 13             40.62             40.62        0.0
# 14             27.07             27.10        0.0
# 15             17.60             17.62        0.0
# 16            358.40            358.43        0.0
# 17             21.18             21.18        0.0
# 18             28.91             28.92        0.0
# 19              6.20              6.20        0.0
# 20            694.04            694.10        0.0
# 21             71.67             71.73        0.0
# 22            110.28            110.35        0.0
# 23             28.53             28.56        0.0
#
#     Number of Grid Visited Per Time Step during Exploration  \
# 0                                                0.02
# 1                                                0.02
# 2                                                0.02
# 3                                                0.02
# 4                                                0.08
# 5                                                0.05
# 6                                                0.04
# 7                                                0.05
# 8                                                0.03
# 9                                                0.02
# 10                                               0.02
# 11                                               0.03
# 12                                               0.06
# 13                                               0.07
# 14                                               0.07
# 15                                               0.06
# 16                                               0.02
# 17                                               0.02
# 18                                               0.03
# 19                                               0.04
# 20                                               0.08
# 21                                               0.07
# 22                                               0.07
# 23                                               0.05
#
#     Number of Grid Visited Per Path Length during Exploration
# 0                                                0.03
# 1                                                0.02
# 2                                                0.02
# 3                                                0.02
# 4                                                0.11
# 5                                                0.07
# 6                                                0.08
# 7                                                0.08
# 8                                                0.03
# 9                                                0.03
# 10                                               0.02
# 11                                               0.04
# 12                                               0.08
# 13                                               0.10
# 14                                               0.08
# 15                                               0.07
# 16                                               0.03
# 17                                               0.04
# 18                                               0.04
# 19                                               0.06
# 20                                               0.10
# 21                                               0.10
# 22                                               0.10
# 23                                               0.07

# %%
summary_mean.to_csv('summary_mean.csv', sep = ',', index = False)
summary_std.to_csv('summary_std.csv', sep = ',', index = False)
